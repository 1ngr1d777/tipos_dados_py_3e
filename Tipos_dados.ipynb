# %% [markdown]
# <a href="https://colab.research.google.com/github/1ngr1d777/tipos_dados_py_3e/blob/main/Tipos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tipos de dados no pytho - revisão

#int
idade = 17
print ("idade: ")
print(idade)
print(type(idade))

#float (ponto flutuante) valores com virgula ( ponto separador de descimais)
altura = 1.60
print ("altura: ")
print(altura)
print(type(altura))

#str (string) texto
nome = "Ingrid Linda"

#bool - booleano: o que é um boleano galera (sim, nao, verdade, mentira, ligado, desligado) ou seja só há duas opções
briga = False

#list Lista (coleção ordenada)
frutas = ["blueberry","morango","manga" ]

#tuble - dupla, como por exemplo, coordenadas
coordenadas = (52.640, 24.325)

#set - conjunto
numeros = {1, 2, 2, 3, 3, 4, 5, 5, 5}

#dict - dicionario
pessoas = {"Nome": "Ingrid Linda", "idade":17}

#none Type = quando não tem nada, mas preciso informar um valor
valor = None
